# %%
import os
os.environ['DJANGO_ALLOW_ASYNC_UNSAFE'] = 'true'

# %%
import pandas as pd
import numpy as np

# %%
from myapp.models import Datas

# %%
db = Datas.objects.all()
df = pd.DataFrame(db.values())

# %%
jumlah_siswa = 116

# %%
df_lari = df.copy()

# %%
df_lari = df_lari[['nama_siswa', 'jenis_kelamin', 'tinggi_badan', 'berat_badan', 'kemampuan_fisik_lari', 'teknik_dasar_lari', 'hasil_bakat_lari']]

# %%
df_voli = df.copy()

# %%
df_voli

# %%
	df_voli = df_voli[['nama_siswa', 'jenis_kelamin', 'tinggi_badan', 'berat_badan', 'kemampuan_fisik_voli', 'teknik_dasar_voli', 'hasil_baka_voli']]

# %%
df.head()
# Out:
#    id             nama_siswa jenis_kelamin  tinggi_badan  berat_badan  \
# 0   1           Abdul Rahman     laki-laki           145           35
# 1   2                 Aditya     laki-laki           152           48
# 2   3              Afdal Ali     laki-laki           147           39
# 3   4  Ahmad Saiful Sudiarto     laki-laki           144           34
# 4   5             Aldi Wali      laki-laki           156           38
#
#    kemampuan_fisik_lari  teknik_dasar_lari hasil_bakat_lari  \
# 0                    80                 80               80
# 1                    80                 80               80
# 2                    90                 90               90
# 3                    90                 90               90
# 4                    85                 85               85
#
#    kemampuan_fisik_voli  teknik_dasar_voli  ... hasil_bakat_bulu_tangkis  \
# 0                    97                 95  ...                       90
# ...
